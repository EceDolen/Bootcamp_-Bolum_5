# %% [markdown]
# 1. sakila database'i zip olarak indiriniz ve extract ediniz.
#
# 2. sakila-db schema.sql kullanarak gerekli tanımları(veri tabanı, tablo, index) yapınız.
#
# 3. sakila-db data.sql'i kullanarak verileri yükleyiniz ve sonrasında MySQL Workbench aracılığıyla schema refresh yaparak şema ve tablolarınızın yüklendiğini teyit ediniz.

# %% [markdown]
# ![Capture1.JPG](attachment:Capture1.JPG)
