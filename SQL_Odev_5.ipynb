# %% [markdown]
# 1) Maximum kredi limiti nedir? Hangi müşteriye ait?
#
# 2) Her ülkeden kaç müşteri var?
#
# 3) En az sipariş veren müşteri numarası ve sipariş sayısı nedir (orders tablosundan)?

# %%
import pandas as pd
import numpy as np
import warnings

# %% [markdown]
# 2. Maximum kredi limiti nedir? Hangi müşteriye ait?

# %%
max_kredi_limit_musterisi = pd.read_csv("data/max_kredi_limit_musterisi.csv")
max_kredi_limit_musterisi
# Out:
#         customerName  kredi_limit_max
# 0  Atelier graphique         227600.0

# %% [markdown]
# 2. Her ülkeden kaç müşteri var?

# %%
ulke_basina_musteri = pd.read_csv("data/ulke_basina_musteri_sayisi.csv")
ulke_basina_musteri
# Out:
#          country  count(*)
# 0         France        12
# 1            USA        36
# 2      Australia         5
# 3         Norway         3
# 4         Poland         1
# 5        Germany        13
# 6          Spain         7
# 7         Sweden         2
# 8        Denmark         2
# 9      Singapore         3
# 10      Portugal         2
# 11         Japan         2
# 12       Finland         3
# 13            UK         5
# 14       Ireland         2
# 15        Canada         3
# 16     Hong Kong         1
# 17         Italy         4
# 18   Switzerland         3
# 19   Netherlands         1
# 20       Belgium         2
# 21   New Zealand         4
# 22  South Africa         1
# 23       Austria         2
# 24   Philippines         1
# 25        Russia         1
# 26        Israel         1

# %% [markdown]
# 3.  En az sipariş veren müşteri numarası ve sipariş sayısı nedir (orders tablosundan)?

# %%
en_az_siparis_veren_musteri = pd.read_csv('data/en_az_siparis_veren_musteri.csv')
en_az_siparis_veren_musteri
# Out:
#     orderNumber  customerNumber  count(*)
# 0         10296             415         1
# 1         10228             173         2
# 2         10161             227         2
# 3         10191             259         2
# 4         10196             455         2
# 5         10206             202         2
# 6         10235             260         2
# 7         10242             456         2
# 8         10149             487         2
# 9         10210             177         2
# 10        10276             204         2
# 11        10222             239         2
# 12        10195             319         2
# 13        10183             339         2
# 14        10186             489         2
# 15        10232             240         2
# 16        10177             344         2
# 17        10207             495         2
# 18        10160             347         2
# 19        10187             211         2
# 20        10280             249         2
# ...

# %% [markdown]
# En az siparis veren musteri numarasi 415 ve siparis adeti birdir.
