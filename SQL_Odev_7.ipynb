# %% [markdown]
# 1. mysql veri tabanında odev isminde bir kullanıcı tanımlayınız. --parolasını siz belirleyiniz
#
# 2. odev kullanıcısına sakila şeması için SELECT yetkisi veriniz. (MySQL Kurulumu ve Veri Tabanı Tanımlama konusunun alıştırmalarında bu veri tabanını tanımlamış ve yeni tablolara verileri yüklemiştik...)
#
# 3. sakila şemasında yer alan customer tablosundan first_name ve last_name alanlarını sorgulayarak ekrana döktüren python kodu yazınız.

# %% [markdown]
# Anaconda command ekrani ile gerekli kullanici tanimlandi

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 2. odev kullanıcısına sakila şeması için SELECT yetkisi veriniz.

# %%
from sqlalchemy import create_engine

# %%
engine_sakila = create_engine('mysql+mysqlconnector://odev:password@localhost/sakila')
#sakila dosyasina tam erisim sagladik.

# %%
engine_sakila.table_names()
# Out:
# ['actor',
#  'address',
#  'category',
#  'city',
#  'country',
#  'customer',
#  'film',
#  'film_actor',
#  'film_category',
#  'film_text',
#  'inventory',
#  'language',
#  'payment',
#  'rental',
#  'staff',
#  'store']

# %%
connection = engine_sakila.connect()

# %% [markdown]
# 3. sakila şemasında yer alan customer tablosundan first_name ve last_name alanlarını sorgulayarak ekrana döktüren python kodu yazınız

# %%
result = connection.execute("select first_name, last_name from customer")
for row in result:
    print("Musteri ismi:", row ["first_name"], row["last_name"])
# Out:
# Musteri ismi: MARY SMITH
# Musteri ismi: PATRICIA JOHNSON
# Musteri ismi: LINDA WILLIAMS
# Musteri ismi: BARBARA JONES
# Musteri ismi: ELIZABETH BROWN
# Musteri ismi: JENNIFER DAVIS
# Musteri ismi: MARIA MILLER
# Musteri ismi: SUSAN WILSON
# Musteri ismi: MARGARET MOORE
# Musteri ismi: DOROTHY TAYLOR
# Musteri ismi: LISA ANDERSON
# Musteri ismi: NANCY THOMAS
# Musteri ismi: KAREN JACKSON
# Musteri ismi: BETTY WHITE
# Musteri ismi: HELEN HARRIS
# Musteri ismi: SANDRA MARTIN
# Musteri ismi: DONNA THOMPSON
# Musteri ismi: CAROL GARCIA
# Musteri ismi: RUTH MARTINEZ
# Musteri ismi: SHARON ROBINSON
# Musteri ismi: MICHELLE CLARK
# Musteri ismi: LAURA RODRIGUEZ
# Musteri ismi: SARAH LEWIS
# Musteri ismi: KIMBERLY LEE
# Musteri ismi: DEBORAH WALKER
# Musteri ismi: JESSICA HALL
# Musteri ismi: SHIRLEY ALLEN
# Musteri ismi: CYNTHIA YOUNG
# Musteri ismi: ANGELA HERNANDEZ
# Musteri ismi: MELISSA KING
# Musteri ismi: BRENDA WRIGHT
# Musteri ismi: AMY LOPEZ
# Musteri ismi: ANNA HILL
# ...
